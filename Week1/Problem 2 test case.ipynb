# %% [markdown]
# Problem 2
#
# Assume s is a string of lower case characters.
#
# Write a program that prints the number of times the string 'bob' occurs in s. For example, if s = 'azcbobobegghakl', then your program should print
#
# Number of times bob occurs is: 2

# %% [markdown]
# Test case:
# INCORRECT Hide outputHide output
# s = 'bobobaobobobbobslboboboboboobxbobobbobbboobobbfy'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 13
#
# s = 'cbobbbeoboovu'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 1
#
# s = 'obobbkboboobbobobbborob'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 4
#
# s = 'obobbbfxo'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 1
#
# s = 'oexobobopbob'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 2
#
# s = 'fooboboobobbboob'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 2
#
# s = 'boobryxxobbbob'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 1
#
# s = 'ahohchshwgww'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 0
#
# s = 'bobobobobobobobobobobobob'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 12
#
# s = 'bobblboboou'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 2
#
# s = 'obobbobcobooobob'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 3
#
# s = 'bobobobobzmpoitobl'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 4
#
# s = 'booboboguobobibobobobo'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 5
#
# s = 'ywbobboobrvb'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 1
#
# s = 'fobobobbobbobobobboobbobbvoobbobbobobobvqooboobo'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 11
#
# s = 'lhobbobbbobbbybs'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 2
#
# s = 'wlboobtbogboob'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 0
#
# s = 'obobcobobbbobob'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 4
#
# s = 'bobbobbobobbobboobfmobobbobbobobbobbbobbobobo'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 13
#
# s = 'booboboboobooqlkbxu'
# Your output:
# here
#
#
# *** ERROR: Expected to find a number in the line 'here
#
# '. ***
# Correct output:
# Number of times 'bob' occurs is: 2
