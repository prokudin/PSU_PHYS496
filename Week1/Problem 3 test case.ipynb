# %% [markdown]
# Problem 3
#
# Assume s is a string of lower case characters.
#
# Write a program that prints the longest substring of s in which the letters occur in alphabetical order. For example, if s = 'azcbobobegghakl', then your program should print
#
# Longest substring in alphabetical order is: beggh
# In the case of ties, print the first substring. For example, if s = 'abcbcd', then your program should print
#
# Longest substring in alphabetical order is: abc
# Note: This problem may be challenging. We encourage you to work smart. If you've spent more than a few hours on this problem, we suggest that you move on to a different part of the course. If you have time, come back to this problem after you've had a break and cleared your head.

# %% [markdown]
# Test case:
# INCORRECT Hide outputHide output
# s = 'dkazaagummwmwpmpluwszkk'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: aagu
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: aagu
#
# s = 'ebxbhmoomozwxf'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: bhmoo
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: bhmoo
#
# s = 'mdpglbauojro'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: dp
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: dp
#
# s = 'mtyjdsytfedemiritqaqhhnl'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: mty
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: mty
#
# s = 'ytxqdfzspljct'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: dfz
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: dfz
#
# s = 'ngpstyfphmmkgtpqgvzqgbz'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: gpsty
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: gpsty
#
# s = 'tbytxdjizgkzzjse'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: gkzz
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: gkzz
#
# s = 'abcdefghijklmnopqrstuvwxyz'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: abcdefghijklmnopqrstuvwxyz
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: abcdefghijklmnopqrstuvwxyz
#
# s = 'czykatpuaeakszsrlxqzwza'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: aksz
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: aksz
#
# s = 'ifjpdcsaxbuqj'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: fjp
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: fjp
#
# s = 'agwpkapqchuxwnrvuddu'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: chux
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: chux
#
# s = 'zyxwvutsrqponmlkjihgfedcba'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: z
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: z
#
# s = 'xupanueeipq'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: eeipq
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: eeipq
#
# s = 'qgdzwwdcwdatms'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: dz
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: dz
#
# s = 'aoqcvvnnbr'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: aoq
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: aoq
#
# s = 'cdmbuqebwxsp'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: cdm
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: cdm
#
# s = 'yltbygyuajerrpppl'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: err
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: err
#
# s = 'kpspemnvpitjy'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: emnv
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: emnv
#
# s = 'qwpjtrtbwhhyycmpwaquxhku'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: hhyy
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: hhyy
#
# s = 'ztjhlhsfwahzym'
# Your output:
# here
#
#
# *** ERROR: Be sure your answer is in the proper format. Your answer should read:
# Longest substring in alphabetical order is: ahz
#
#
# Your answer is not in the form '(words): (answer)'. Please fix your output to match the problem specifications. ***
# Correct output:
# Longest substring in alphabetical order is: ahz
